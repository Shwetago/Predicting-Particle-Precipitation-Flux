# %% [markdown]
# ## Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import os

# from keras import backend as K
import keras
from keras import utils, models, layers, optimizers
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from keras.layers import Dense, GRU, BatchNormalization, Activation, LSTM, Flatten
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
from keras.models import load_model
from keras.layers import Dropout
import tensorflow as tf
from tensorflow.keras.optimizers import Adam, SGD
from keras.models import Sequential

# %%
# Reading the csv file
df = pd.read_csv('AI_Ready_DMSP_Data.csv')

# %%
# printing first few rows of the dataset
df.head()
# Out:
#              Datetimes  SC_AACGM_LAT  SC_AACGM_LTIME  ELE_TOTAL_ENERGY_FLUX  \
# 0  1987-01-12 12:57:00     51.143220        5.664024           2.057827e+08
# 1  1987-01-12 12:58:00     54.137207        5.535848           2.509837e+08
# 2  1987-01-12 13:01:00     62.928176        5.031172           4.469146e+08
# 3  1987-01-12 13:02:00     65.719631        4.794780           1.934849e+10
# 4  1987-01-12 13:03:00     68.392364        4.507448           3.913337e+11
#
#    ELE_TOTAL_ENERGY_FLUX_STD  ELE_AVG_ENERGY  ELE_AVG_ENERGY_STD  ID_SC  \
# 0                   0.411230        39.89341            0.411485    6.0
# 1                   0.478268        40.82392            0.478568    6.0
# 2                   0.603362       143.77360            0.604023    6.0
# 3                   0.103648       820.36560            0.103671    6.0
# 4                   0.114959      5291.57100            0.114959    6.0
#
#      sin_ut    cos_ut  ...  AE_5min  AL_5min  AU_5min  SymH_5min  PC_5min  \
# 0 -0.246153 -0.969231  ...     86.0    -61.0     25.0        3.0     0.77
# 1 -0.250380 -0.968148  ...     86.0    -61.0     25.0        3.0     0.77
# 2 -0.263031 -0.964787  ...     82.0    -58.0     24.0        3.0     0.77
# 3 -0.267238 -0.963630  ...     82.0    -58.0     24.0        3.0     0.77
# 4 -0.271440 -0.962455  ...     82.0    -58.0     24.0        3.0     0.77
#
#    vsw_5min  vx_5min  psw_5min  borovsky_5min  newell_5min
# 0     356.0   -355.5      2.96   17439.640589  2489.686963
# 1     356.0   -355.5      2.96   17439.640589  2489.686963
# 2     354.7   -354.1      3.20   14199.368957  1847.748015
# 3     354.7   -354.1      3.20   14199.368957  1847.748015
# 4     354.7   -354.1      3.20   14199.368957  1847.748015
#
# [5 rows x 154 columns]

# %%
df.shape
# Out:
# (77367, 154)

# %%
# creating the copy of the dataset
df_cumulative = df.copy()

# %%
# changing the date column into datetime format
df_cumulative = df_cumulative.set_index('Datetimes')
df_cumulative.index = pd.to_datetime(df_cumulative.index)

# %%
# list the columns
df_cumulative.columns.to_list()
# Out:
# ['SC_AACGM_LAT',
#  'SC_AACGM_LTIME',
#  'ELE_TOTAL_ENERGY_FLUX',
#  'ELE_TOTAL_ENERGY_FLUX_STD',
#  'ELE_AVG_ENERGY',
#  'ELE_AVG_ENERGY_STD',
#  'ID_SC',
#  'sin_ut',
#  'cos_ut',
#  'sin_doy',
#  'cos_doy',
#  'sin_SC_AACGM_LTIME',
#  'cos_SC_AACGM_LTIME',
#  'F107',
#  'Bz',
#  'By',
#  'Bx',
#  'AE',
#  'AL',
#  'AU',
#  'SymH',
#  'PC',
#  'vsw',
#  'vx',
#  'psw',
#  'borovsky',
#  'newell',
#  'F107_6hr',
#  'Bz_6hr',
#  'By_6hr',
#  'Bx_6hr',
#  'AE_6hr',
#  'AL_6hr',
#  'AU_6hr',
#  'SymH_6hr',
#  'PC_6hr',
#  'vsw_6hr',
#  'vx_6hr',
#  'psw_6hr',
#  'borovsky_6hr',
#  'newell_6hr',
#  'F107_5hr',
#  'Bz_5hr',
#  'By_5hr',
#  'Bx_5hr',
#  'AE_5hr',
#  'AL_5hr',
#  'AU_5hr',
#  'SymH_5hr',
#  'PC_5hr',
#  'vsw_5hr',
#  'vx_5hr',
#  'psw_5hr',
#  'borovsky_5hr',
#  'newell_5hr',
#  'F107_3hr',
#  'Bz_3hr',
#  'By_3hr',
#  'Bx_3hr',
#  'AE_3hr',
#  'AL_3hr',
#  'AU_3hr',
#  'SymH_3hr',
#  'PC_3hr',
#  'vsw_3hr',
#  'vx_3hr',
#  'psw_3hr',
#  'borovsky_3hr',
#  'newell_3hr',
#  'F107_1hr',
#  'Bz_1hr',
#  'By_1hr',
#  'Bx_1hr',
#  'AE_1hr',
#  'AL_1hr',
#  'AU_1hr',
#  'SymH_1hr',
#  'PC_1hr',
#  'vsw_1hr',
#  'vx_1hr',
#  'psw_1hr',
#  'borovsky_1hr',
#  'newell_1hr',
#  'F107_45min',
#  'Bz_45min',
#  'By_45min',
#  'Bx_45min',
#  'AE_45min',
#  'AL_45min',
#  'AU_45min',
#  'SymH_45min',
#  'PC_45min',
#  'vsw_45min',
#  'vx_45min',
#  'psw_45min',
#  'borovsky_45min',
#  'newell_45min',
#  'F107_30min',
#  'Bz_30min',
#  'By_30min',
#  'Bx_30min',
#  'AE_30min',
#  'AL_30min',
#  'AU_30min',
#  'SymH_30min',
#  'PC_30min',
#  'vsw_30min',
#  'vx_30min',
#  'psw_30min',
#  'borovsky_30min',
#  'newell_30min',
#  'F107_15min',
#  'Bz_15min',
#  'By_15min',
#  'Bx_15min',
#  'AE_15min',
#  'AL_15min',
#  'AU_15min',
#  'SymH_15min',
#  'PC_15min',
#  'vsw_15min',
#  'vx_15min',
#  'psw_15min',
#  'borovsky_15min',
#  'newell_15min',
#  'F107_10min',
#  'Bz_10min',
#  'By_10min',
#  'Bx_10min',
#  'AE_10min',
#  'AL_10min',
#  'AU_10min',
#  'SymH_10min',
#  'PC_10min',
#  'vsw_10min',
#  'vx_10min',
#  'psw_10min',
#  'borovsky_10min',
#  'newell_10min',
#  'F107_5min',
#  'Bz_5min',
#  'By_5min',
#  'Bx_5min',
#  'AE_5min',
#  'AL_5min',
#  'AU_5min',
#  'SymH_5min',
#  'PC_5min',
#  'vsw_5min',
#  'vx_5min',
#  'psw_5min',
#  'borovsky_5min',
#  'newell_5min']

# %%
# Choose columns to drop
cols_to_drop = [c for c in df_cumulative.columns if ('1min' in c) | ('3min' in c) | ('4min' in c) | ('_5min'in c) | ('15min' in c)| ('5hr' in c) | ('F107_' in c) | ('vx' in c) | ('AE' in c) | ('newell' in c) | ('borovsky' in c) | ('STD' in c) | ('AVG' in c) | ('SC_AACGM_LTIME'==c)]
df_cumulative = df_cumulative.drop(columns=cols_to_drop)

# %%
# List the new set of columns
df_cumulative.columns.to_list()
# Out:
# ['SC_AACGM_LAT',
#  'ELE_TOTAL_ENERGY_FLUX',
#  'ID_SC',
#  'sin_ut',
#  'cos_ut',
#  'sin_doy',
#  'cos_doy',
#  'sin_SC_AACGM_LTIME',
#  'cos_SC_AACGM_LTIME',
#  'F107',
#  'Bz',
#  'By',
#  'Bx',
#  'AL',
#  'AU',
#  'SymH',
#  'PC',
#  'vsw',
#  'psw',
#  'Bz_6hr',
#  'By_6hr',
#  'Bx_6hr',
#  'AL_6hr',
#  'AU_6hr',
#  'SymH_6hr',
#  'PC_6hr',
#  'vsw_6hr',
#  'psw_6hr',
#  'Bz_3hr',
#  'By_3hr',
#  'Bx_3hr',
#  'AL_3hr',
#  'AU_3hr',
#  'SymH_3hr',
#  'PC_3hr',
#  'vsw_3hr',
#  'psw_3hr',
#  'Bz_1hr',
#  'By_1hr',
#  'Bx_1hr',
#  'AL_1hr',
#  'AU_1hr',
#  'SymH_1hr',
#  'PC_1hr',
#  'vsw_1hr',
#  'psw_1hr',
#  'Bz_45min',
#  'By_45min',
#  'Bx_45min',
#  'AL_45min',
#  'AU_45min',
#  'SymH_45min',
#  'PC_45min',
#  'vsw_45min',
#  'psw_45min',
#  'Bz_30min',
#  'By_30min',
#  'Bx_30min',
#  'AL_30min',
#  'AU_30min',
#  'SymH_30min',
#  'PC_30min',
#  'vsw_30min',
#  'psw_30min',
#  'Bz_10min',
#  'By_10min',
#  'Bx_10min',
#  'AL_10min',
#  'AU_10min',
#  'SymH_10min',
#  'PC_10min',
#  'vsw_10min',
#  'psw_10min']

# %%
print('number of input features total = {}'.format(df_cumulative.shape[1]))
# Out:
# number of input features total = 73

# %%
# Define the threshold above which to remove energy flux values
eflux_threshold_quantile = 99.995
eflux_threshold = .99995

# Define the conversion factor from eV to erg
erg_eV_factor = (1.60218e-12)

# %%
# Remove outliers

print(df_cumulative.shape)
threshold_drop_val = np.percentile(df_cumulative['ELE_TOTAL_ENERGY_FLUX'],eflux_threshold_quantile)
print('... dropping rows where total electron energy flux is greater than {:.4E} [eV/cm2/s/ster]'.format(threshold_drop_val))
print('--------> number dropped = {}'.format(len( np.argwhere(df_cumulative['ELE_TOTAL_ENERGY_FLUX'].values > threshold_drop_val) )))
df_cumulative = df_cumulative[ (df_cumulative['ELE_TOTAL_ENERGY_FLUX'].values < threshold_drop_val) ]
print(df_cumulative.shape)
# Out:
# (77367, 73)
# ... dropping rows where total electron energy flux is greater than 3.9368E+15 [eV/cm2/s/ster]
# --------> number dropped = 4
# (77363, 73)

# %%
df_cumulative.describe()
# Out:
#        SC_AACGM_LAT  ELE_TOTAL_ENERGY_FLUX         ID_SC        sin_ut  \
# count  77363.000000           7.736300e+04  77363.000000  77363.000000
# mean      65.387655           2.942586e+11     12.737420     -0.010660
# std       11.033138           2.247742e+13      1.094167      0.698633
# min       45.000858           6.229923e+06      6.000000     -1.000000
# 25%       56.220178           3.561043e+08     12.000000     -0.704015
# 50%       66.377877           7.890107e+08     13.000000     -0.008727
# 75%       74.094442           1.457374e+10     13.000000      0.672367
# max       89.899278           3.542682e+15     15.000000      1.000000
#
#              cos_ut       sin_doy       cos_doy  sin_SC_AACGM_LTIME  \
# count  77363.000000  77363.000000  77363.000000        77363.000000
# mean       0.005544     -0.439728     -0.180498            0.032396
# std        0.715388      0.520797      0.709112            0.833193
# min       -1.000000     -0.999917     -0.999963           -1.000000
# 25%       -0.722364     -0.849817     -0.838280           -0.915647
# 50%        0.017452     -0.552435     -0.381689            0.212129
# 75%        0.728371     -0.196673      0.527078            0.900469
# max        1.000000      0.999991      1.000000            1.000000
#
#        cos_SC_AACGM_LTIME          F107  ...     psw_30min      Bz_10min  \
# count        77363.000000  77363.000000  ...  77362.000000  77362.000000
# mean            -0.078615    182.061155  ...      1.921658      0.999876
# std              0.546418     42.266323  ...      1.774154      3.436340
# min             -1.000000     68.900000  ...      0.180000     -8.420000
# 25%             -0.492601    146.900000  ...      1.000000     -1.250000
# 50%             -0.115528    178.100000  ...      1.440000      0.870000
# 75%              0.322449    215.100000  ...      2.220000      2.850000
# max              1.000000    284.000000  ...     47.000000     55.470000
#
#            By_10min      Bx_10min      AL_10min      AU_10min    SymH_10min  \
# count  77362.000000  77362.000000  77362.000000  77362.000000  77362.000000
# mean       0.039588     -0.302500    -79.667705     62.627853     -8.822523
# std        4.252604      3.661881     85.741187     53.712068     16.925225
# min      -23.990000    -15.500000   -688.000000    -29.000000   -135.000000
# 25%       -3.040000     -3.120000   -104.000000     24.000000    -16.000000
# 50%        0.100000     -0.470000    -46.000000     46.000000     -7.000000
# 75%        3.150000      2.600000    -24.000000     84.000000      1.000000
# max       23.460000     36.270000     25.000000    379.000000     69.000000
#
#            PC_10min     vsw_10min     psw_10min
# count  77362.000000  77362.000000  77362.000000
# mean       0.588782    405.541934      1.934449
# std        1.098843     72.189518      1.797954
# min       -8.030000    264.600000      0.150000
# 25%       -0.080000    357.400000      1.000000
# 50%        0.410000    394.900000      1.440000
# 75%        1.180000    436.300000      2.240000
# max        9.990000    832.300000     45.760000
#
# [8 rows x 73 columns]

# %%
# separate training data and validation data
mask_val = [(df_cumulative.index.year == 2001) & (df_cumulative['ID_SC'].values>6)]

# %%
# storing the data of the year 2002 as a validation set
df_val = df_cumulative[mask_val[0]].copy(deep=True)
df_val.head()
# Out:
#                      SC_AACGM_LAT  ELE_TOTAL_ENERGY_FLUX  ID_SC    sin_ut  \
# Datetimes
# 2001-01-01 06:51:00     73.922498           3.107251e+08   12.0  0.975342
# 2001-01-01 06:54:00     67.226807           5.408906e+08   12.0  0.972370
# 2001-01-01 06:58:00     55.034913           3.561043e+08   12.0  0.968148
# 2001-01-01 07:00:00     48.654315           3.196454e+08   12.0  0.965926
# 2001-01-01 07:28:00     49.964592           7.835596e+09   12.0  0.927184
#
#                        cos_ut   sin_doy   cos_doy  sin_SC_AACGM_LTIME  \
# Datetimes
# 2001-01-01 06:51:00 -0.220697  0.017213  0.999852           -0.060503
# 2001-01-01 06:54:00 -0.233445  0.017213  0.999852            0.372107
# 2001-01-01 06:58:00 -0.250380  0.017213  0.999852            0.608040
# 2001-01-01 07:00:00 -0.258819  0.017213  0.999852            0.665768
# 2001-01-01 07:28:00 -0.374607  0.017213  0.999852            0.979876
#
#                      cos_SC_AACGM_LTIME   F107  ...  psw_30min  Bz_10min  \
# Datetimes                                       ...
# 2001-01-01 06:51:00           -0.998168  165.3  ...       2.29     -2.41
# 2001-01-01 06:54:00           -0.928190  165.3  ...       2.29     -2.41
# 2001-01-01 06:58:00           -0.793907  165.3  ...       1.90     -2.57
# 2001-01-01 07:00:00           -0.746159  165.3  ...       2.27     -2.29
# 2001-01-01 07:28:00           -0.199608  165.3  ...       2.39     -2.30
#
#                      By_10min  Bx_10min  AL_10min  AU_10min  SymH_10min  \
# Datetimes
# 2001-01-01 06:51:00     -0.34     -3.17    -156.0      40.0        -9.0
# 2001-01-01 06:54:00     -0.34     -3.17    -156.0      40.0        -9.0
# 2001-01-01 06:58:00     -0.34     -3.47    -178.0      45.0        -8.0
# 2001-01-01 07:00:00      0.04     -3.54    -176.0      47.0        -8.0
# 2001-01-01 07:28:00      0.75     -3.76     -26.0      34.0       -10.0
#
#                      PC_10min  vsw_10min  psw_10min
# Datetimes
# 2001-01-01 06:51:00      0.88      290.8       2.70
# 2001-01-01 06:54:00      0.88      290.8       2.70
# 2001-01-01 06:58:00      0.93      288.5       2.34
# 2001-01-01 07:00:00      0.80      288.6       2.34
# 2001-01-01 07:28:00      0.43      286.6       1.84
#
# [5 rows x 73 columns]

# %%
# storing rest of the data as training data
df_train = df_cumulative.copy(deep=True).drop( df_cumulative.index[mask_val[0]])
df_train.head()
# Out:
#                      SC_AACGM_LAT  ELE_TOTAL_ENERGY_FLUX  ID_SC    sin_ut  \
# Datetimes
# 1987-01-12 12:57:00     51.143220           2.057827e+08    6.0 -0.246153
# 1987-01-12 12:58:00     54.137207           2.509837e+08    6.0 -0.250380
# 1987-01-12 13:01:00     62.928176           4.469146e+08    6.0 -0.263031
# 1987-01-12 13:02:00     65.719631           1.934849e+10    6.0 -0.267238
# 1987-01-12 13:03:00     68.392364           3.913337e+11    6.0 -0.271440
#
#                        cos_ut   sin_doy  cos_doy  sin_SC_AACGM_LTIME  \
# Datetimes
# 1987-01-12 12:57:00 -0.969231  0.205104  0.97874            0.996134
# 1987-01-12 12:58:00 -0.968148  0.205104  0.97874            0.992626
# 1987-01-12 13:01:00 -0.964787  0.205104  0.97874            0.968006
# 1987-01-12 13:02:00 -0.963630  0.205104  0.97874            0.950633
# 1987-01-12 13:03:00 -0.962455  0.205104  0.97874            0.924624
#
#                      cos_SC_AACGM_LTIME  F107  ...  psw_30min  Bz_10min  \
# Datetimes                                      ...
# 1987-01-12 12:57:00            0.087845  68.9  ...       3.61      1.25
# 1987-01-12 12:58:00            0.121216  68.9  ...       3.61      1.25
# 1987-01-12 13:01:00            0.250928  68.9  ...       3.66      1.51
# 1987-01-12 13:02:00            0.310316  68.9  ...       3.66      1.51
# 1987-01-12 13:03:00            0.380881  68.9  ...       3.66      1.51
#
#                      By_10min  Bx_10min  AL_10min  AU_10min  SymH_10min  \
# Datetimes
# 1987-01-12 12:57:00      6.52     -3.03     -36.0      19.0         4.0
# 1987-01-12 12:58:00      6.52     -3.03     -36.0      19.0         4.0
# 1987-01-12 13:01:00      6.42     -2.72     -61.0      25.0         3.0
# 1987-01-12 13:02:00      6.42     -2.72     -61.0      25.0         3.0
# 1987-01-12 13:03:00      6.42     -2.72     -61.0      25.0         3.0
#
#                      PC_10min  vsw_10min  psw_10min
# Datetimes
# 1987-01-12 12:57:00      0.71      364.4       3.09
# 1987-01-12 12:58:00      0.71      364.4       3.09
# 1987-01-12 13:01:00      0.77      356.0       2.96
# 1987-01-12 13:02:00      0.77      356.0       2.96
# 1987-01-12 13:03:00      0.77      356.0       2.96
#
# [5 rows x 73 columns]

# %%
# dropping one null row in validation set
df_val.dropna(inplace=True)

# %%
print('validation data shape = {}'.format(df_val.shape))
print('train data shape = {}'.format(df_train.shape))
# Out:
# validation data shape = (72711, 73)
# train data shape = (4651, 73)

# %%
# Construct X and y
from sklearn.preprocessing import StandardScaler
feature_cols = [c for c in df_cumulative.columns if not 'ELE' in c]

X_val = df_val[feature_cols].copy(deep=True)
y_val = df_val['ELE_TOTAL_ENERGY_FLUX'].copy(deep=True)
X_train = df_train[feature_cols].copy(deep=True)
y_train = df_train['ELE_TOTAL_ENERGY_FLUX'].copy(deep=True)
scaler_X = StandardScaler()
scaler_X = scaler_X.fit(X_train.values)
X_val_scaled = scaler_X.transform(X_val.values)
X_train_scaled = scaler_X.transform(X_train.values)

# %%
# The units of the energy flux are eV/cm2/s/ster
#   --> To remove the 'steradian' multiply by PI (see: https://agupubs.onlinelibrary.wiley.com/doi/epdf/10.1002/2016JA023339)
y_train = y_train * np.pi
y_val = y_val * np.pi
print('NOTE: removing the steradian from the DMSP data BEFORE training')

# Create targets in erg/cm2/s units to explore target in different units
y_train_erg = y_train.copy(deep=True) * (1.60218e-12)
y_val_erg = y_val.copy(deep=True) * (1.60218e-12)

# Create targets in log10(eV/cm2/s) units to explore target in different units
y_train[y_train == 0] = 0.00001
y_val[y_val == 0] = 0.00001
y_train_log = np.log10(y_train.copy(deep=True))
y_val_log = np.log10(y_val.copy(deep=True))
# Out:
# NOTE: removing the steradian from the DMSP data BEFORE training

# %%
# creating the function for calculation of R2-score
from keras import backend as K
def r2_score(y_true, y_pred):
    SS_res =  K.sum(K.square( y_true-y_pred ))
    SS_tot = K.sum(K.square( y_true - K.mean(y_true) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()) )

# %%
# LeakyReLU activation function is used instead of ReLU since the input features have negative values as well
import keras
model1 = Sequential()
model1.add(Dense(128, input_shape=(X_train_scaled.shape[1:]), kernel_initializer='uniform', activation = keras.layers.LeakyReLU(alpha=0.01)))

model1.add(Dense(64, kernel_initializer='uniform', activation=keras.layers.LeakyReLU(alpha=0.01)))

model1.add(Dense(32, kernel_initializer='uniform', activation=keras.layers.LeakyReLU(alpha=0.01)))

model1.add(Dense(1, kernel_initializer='uniform',activation='linear'))
# Compile the model
opt = Adam() # specifying the optimizer used for the model
model1.compile(loss='mean_squared_error', optimizer=opt, metrics=[tf.keras.metrics.RootMeanSquaredError(name="root_mean_squared_error", dtype=None),r2_score])

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               9344
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 19,713
# Trainable params: 19,713
# Non-trainable params: 0
# _________________________________________________________________

# %%
curr_dt_time = datetime.datetime.now()
# spefying the format in which model needs to be saved
model_name = 'DMSP1' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'

if not os.path.exists(model_name):
    os.mkdir(model_name)
 # giving the file path
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{root_mean_squared_error:.5f}-{val_loss:.5f}-{val_root_mean_squared_error:.5f}.h5'
# Creating the call back for saving only the best models
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
# creating the callback for early stopping
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=8)

callbacks_list = [checkpoint, early_stopping]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model1.fit(X_train_scaled,y_train_log, validation_data=(X_val_scaled, y_val_log), epochs=50, batch_size=64, verbose=1, shuffle=False, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 66/73 [==========================>...] - ETA: 0s - loss: 68.0467 - root_mean_squared_error: 8.2490 - r2_score: -50.1054
# Epoch 1: val_loss improved from inf to 37.63978, saving model to DMSP1_2023-08-2010_24_44.014190/model-00001-62.29885-7.89296-37.63978-6.13513.h5
# 73/73 [==============================] - 4s 36ms/step - loss: 62.2989 - root_mean_squared_error: 7.8930 - r2_score: -45.7198 - val_loss: 37.6398 - val_root_mean_squared_error: 6.1351 - val_r2_score: -33.0633
# Epoch 2/50
# 72/73 [============================>.] - ETA: 0s - loss: 8.4721 - root_mean_squared_error: 2.9107 - r2_score: -4.5850
# Epoch 2: val_loss improved from 37.63978 to 10.53665, saving model to DMSP1_2023-08-2010_24_44.014190/model-00002-8.40385-2.89894-10.53665-3.24602.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 8.4039 - root_mean_squared_error: 2.8989 - r2_score: -4.5210 - val_loss: 10.5367 - val_root_mean_squared_error: 3.2460 - val_r2_score: -8.7594
# Epoch 3/50
# 68/73 [==========================>...] - ETA: 0s - loss: 3.5646 - root_mean_squared_error: 1.8880 - r2_score: -1.4605
# Epoch 3: val_loss did not improve from 10.53665
# 73/73 [==============================] - 3s 41ms/step - loss: 3.4234 - root_mean_squared_error: 1.8502 - r2_score: -1.3805 - val_loss: 10.8662 - val_root_mean_squared_error: 3.2964 - val_r2_score: -9.0635
# Epoch 4/50
# 58/73 [======================>.......] - ETA: 0s - loss: 2.7263 - root_mean_squared_error: 1.6511 - r2_score: -0.8575
# Epoch 4: val_loss did not improve from 10.53665
# 73/73 [==============================] - 3s 38ms/step - loss: 2.4145 - root_mean_squared_error: 1.5539 - r2_score: -0.7096 - val_loss: 10.8848 - val_root_mean_squared_error: 3.2992 - val_r2_score: -9.1141
# Epoch 5/50
# 68/73 [==========================>...] - ETA: 0s - loss: 1.9368 - root_mean_squared_error: 1.3917 - r2_score: -0.3937
# Epoch 5: val_loss did not improve from 10.53665
# 73/73 [==============================] - 3s 39ms/step - loss: 1.8813 - root_mean_squared_error: 1.3716 - r2_score: -0.3688 - val_loss: 10.5886 - val_root_mean_squared_error: 3.2540 - val_r2_score: -8.8387
# Epoch 6/50
# 70/73 [===========================>..] - ETA: 0s - loss: 1.6480 - root_mean_squared_error: 1.2837 - r2_score: -0.2118
# Epoch 6: val_loss improved from 10.53665 to 10.49586, saving model to DMSP1_2023-08-2010_24_44.014190/model-00006-1.62838-1.27608-10.49586-3.23973.h5
# 73/73 [==============================] - 2s 28ms/step - loss: 1.6284 - root_mean_squared_error: 1.2761 - r2_score: -0.2074 - val_loss: 10.4959 - val_root_mean_squared_error: 3.2397 - val_r2_score: -8.7740
# Epoch 7/50
# 56/73 [======================>.......] - ETA: 0s - loss: 1.6837 - root_mean_squared_error: 1.2976 - r2_score: -0.1814
# Epoch 7: val_loss improved from 10.49586 to 10.25837, saving model to DMSP1_2023-08-2010_24_44.014190/model-00007-1.52441-1.23467-10.25837-3.20287.h5
# 73/73 [==============================] - 2s 29ms/step - loss: 1.5244 - root_mean_squared_error: 1.2347 - r2_score: -0.1408 - val_loss: 10.2584 - val_root_mean_squared_error: 3.2029 - val_r2_score: -8.5619
# Epoch 8/50
# 63/73 [========================>.....] - ETA: 0s - loss: 1.5361 - root_mean_squared_error: 1.2394 - r2_score: -0.1228
# Epoch 8: val_loss improved from 10.25837 to 10.02304, saving model to DMSP1_2023-08-2010_24_44.014190/model-00008-1.46725-1.21130-10.02304-3.16592.h5
# 73/73 [==============================] - 3s 41ms/step - loss: 1.4673 - root_mean_squared_error: 1.2113 - r2_score: -0.1025 - val_loss: 10.0230 - val_root_mean_squared_error: 3.1659 - val_r2_score: -8.3353
# Epoch 9/50
# 70/73 [===========================>..] - ETA: 0s - loss: 1.4424 - root_mean_squared_error: 1.2010 - r2_score: -0.0797
# Epoch 9: val_loss improved from 10.02304 to 9.79861, saving model to DMSP1_2023-08-2010_24_44.014190/model-00009-1.42700-1.19457-9.79861-3.13027.h5
# 73/73 [==============================] - 2s 28ms/step - loss: 1.4270 - root_mean_squared_error: 1.1946 - r2_score: -0.0769 - val_loss: 9.7986 - val_root_mean_squared_error: 3.1303 - val_r2_score: -8.1264
# Epoch 10/50
# 72/73 [============================>.] - ETA: 0s - loss: 1.3857 - root_mean_squared_error: 1.1771 - r2_score: -0.0491
# Epoch 10: val_loss improved from 9.79861 to 9.66389, saving model to DMSP1_2023-08-2010_24_44.014190/model-00010-1.38412-1.17648-9.66389-3.10868.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3841 - root_mean_squared_error: 1.1765 - r2_score: -0.0487 - val_loss: 9.6639 - val_root_mean_squared_error: 3.1087 - val_r2_score: -7.9948
# Epoch 11/50
# 67/73 [==========================>...] - ETA: 0s - loss: 1.3869 - root_mean_squared_error: 1.1777 - r2_score: -0.0383
# Epoch 11: val_loss improved from 9.66389 to 9.59850, saving model to DMSP1_2023-08-2010_24_44.014190/model-00011-1.34857-1.16128-9.59850-3.09814.h5
# 73/73 [==============================] - 2s 27ms/step - loss: 1.3486 - root_mean_squared_error: 1.1613 - r2_score: -0.0250 - val_loss: 9.5985 - val_root_mean_squared_error: 3.0981 - val_r2_score: -7.9364
# Epoch 12/50
# 57/73 [======================>.......] - ETA: 0s - loss: 1.4225 - root_mean_squared_error: 1.1927 - r2_score: -0.0359
# Epoch 12: val_loss improved from 9.59850 to 9.50730, saving model to DMSP1_2023-08-2010_24_44.014190/model-00012-1.31933-1.14862-9.50730-3.08339.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3193 - root_mean_squared_error: 1.1486 - r2_score: -0.0055 - val_loss: 9.5073 - val_root_mean_squared_error: 3.0834 - val_r2_score: -7.8485
# Epoch 13/50
# 66/73 [==========================>...] - ETA: 0s - loss: 1.3351 - root_mean_squared_error: 1.1555 - r2_score: -0.0025
# Epoch 13: val_loss improved from 9.50730 to 9.46212, saving model to DMSP1_2023-08-2010_24_44.014190/model-00013-1.30159-1.14087-9.46212-3.07606.h5
# 73/73 [==============================] - 3s 41ms/step - loss: 1.3016 - root_mean_squared_error: 1.1409 - r2_score: 0.0072 - val_loss: 9.4621 - val_root_mean_squared_error: 3.0761 - val_r2_score: -7.8042
# Epoch 14/50
# 56/73 [======================>.......] - ETA: 0s - loss: 1.4152 - root_mean_squared_error: 1.1896 - r2_score: -0.0107
# Epoch 14: val_loss improved from 9.46212 to 9.29961, saving model to DMSP1_2023-08-2010_24_44.014190/model-00014-1.29644-1.13861-9.29961-3.04953.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.2964 - root_mean_squared_error: 1.1386 - r2_score: 0.0113 - val_loss: 9.2996 - val_root_mean_squared_error: 3.0495 - val_r2_score: -7.6429
# Epoch 15/50
# 72/73 [============================>.] - ETA: 0s - loss: 1.2940 - root_mean_squared_error: 1.1376 - r2_score: 0.0152
# Epoch 15: val_loss improved from 9.29961 to 9.28363, saving model to DMSP1_2023-08-2010_24_44.014190/model-00015-1.29226-1.13678-9.28363-3.04691.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.2923 - root_mean_squared_error: 1.1368 - r2_score: 0.0160 - val_loss: 9.2836 - val_root_mean_squared_error: 3.0469 - val_r2_score: -7.6127
# Epoch 16/50
# 55/73 [=====================>........] - ETA: 0s - loss: 1.4445 - root_mean_squared_error: 1.2019 - r2_score: -0.0290
# Epoch 16: val_loss improved from 9.28363 to 8.92726, saving model to DMSP1_2023-08-2010_24_44.014190/model-00016-1.30680-1.14316-8.92726-2.98785.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3068 - root_mean_squared_error: 1.1432 - r2_score: 0.0078 - val_loss: 8.9273 - val_root_mean_squared_error: 2.9879 - val_r2_score: -7.2558
# Epoch 17/50
# 70/73 [===========================>..] - ETA: 0s - loss: 1.3246 - root_mean_squared_error: 1.1509 - r2_score: 0.0011
# Epoch 17: val_loss did not improve from 8.92726
# 73/73 [==============================] - 3s 40ms/step - loss: 1.3083 - root_mean_squared_error: 1.1438 - r2_score: 0.0064 - val_loss: 8.9590 - val_root_mean_squared_error: 2.9932 - val_r2_score: -7.2687
# Epoch 18/50
# 69/73 [===========================>..] - ETA: 0s - loss: 1.3587 - root_mean_squared_error: 1.1656 - r2_score: -0.0209
# Epoch 18: val_loss improved from 8.92726 to 8.46456, saving model to DMSP1_2023-08-2010_24_44.014190/model-00018-1.33091-1.15365-8.46456-2.90939.h5
# 73/73 [==============================] - 3s 41ms/step - loss: 1.3309 - root_mean_squared_error: 1.1537 - r2_score: -0.0092 - val_loss: 8.4646 - val_root_mean_squared_error: 2.9094 - val_r2_score: -6.7845
# Epoch 19/50
# 72/73 [============================>.] - ETA: 0s - loss: 1.3310 - root_mean_squared_error: 1.1537 - r2_score: -0.0126
# Epoch 19: val_loss did not improve from 8.46456
# 73/73 [==============================] - 2s 27ms/step - loss: 1.3275 - root_mean_squared_error: 1.1522 - r2_score: -0.0097 - val_loss: 8.8153 - val_root_mean_squared_error: 2.9691 - val_r2_score: -7.0839
# Epoch 20/50
# 71/73 [============================>.] - ETA: 0s - loss: 1.3687 - root_mean_squared_error: 1.1699 - r2_score: -0.0419
# Epoch 20: val_loss improved from 8.46456 to 8.17530, saving model to DMSP1_2023-08-2010_24_44.014190/model-00020-1.36050-1.16640-8.17530-2.85925.h5
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3605 - root_mean_squared_error: 1.1664 - r2_score: -0.0377 - val_loss: 8.1753 - val_root_mean_squared_error: 2.8592 - val_r2_score: -6.4837
# Epoch 21/50
# 58/73 [======================>.......] - ETA: 0s - loss: 1.4374 - root_mean_squared_error: 1.1989 - r2_score: -0.0526
# Epoch 21: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3468 - root_mean_squared_error: 1.1605 - r2_score: -0.0309 - val_loss: 9.1807 - val_root_mean_squared_error: 3.0300 - val_r2_score: -7.3817
# Epoch 22/50
# 65/73 [=========================>....] - ETA: 0s - loss: 1.4575 - root_mean_squared_error: 1.2073 - r2_score: -0.0965
# Epoch 22: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 40ms/step - loss: 1.4090 - root_mean_squared_error: 1.1870 - r2_score: -0.0820 - val_loss: 8.2114 - val_root_mean_squared_error: 2.8656 - val_r2_score: -6.5429
# Epoch 23/50
# 72/73 [============================>.] - ETA: 0s - loss: 1.3879 - root_mean_squared_error: 1.1781 - r2_score: -0.0708
# Epoch 23: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 1.3861 - root_mean_squared_error: 1.1773 - r2_score: -0.0699 - val_loss: 10.6733 - val_root_mean_squared_error: 3.2670 - val_r2_score: -8.7629
# Epoch 24/50
# 71/73 [============================>.] - ETA: 0s - loss: 1.6377 - root_mean_squared_error: 1.2797 - r2_score: -0.2670
# Epoch 24: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 1.6262 - root_mean_squared_error: 1.2752 - r2_score: -0.2595 - val_loss: 9.3532 - val_root_mean_squared_error: 3.0583 - val_r2_score: -7.7680
# Epoch 25/50
# 67/73 [==========================>...] - ETA: 0s - loss: 1.7023 - root_mean_squared_error: 1.3047 - r2_score: -0.2806
# Epoch 25: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 1.7216 - root_mean_squared_error: 1.3121 - r2_score: -0.3305 - val_loss: 12.4527 - val_root_mean_squared_error: 3.5288 - val_r2_score: -10.5024
# Epoch 26/50
# 73/73 [==============================] - ETA: 0s - loss: 2.0043 - root_mean_squared_error: 1.4157 - r2_score: -0.5715
# Epoch 26: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 2.0043 - root_mean_squared_error: 1.4157 - r2_score: -0.5715 - val_loss: 10.3874 - val_root_mean_squared_error: 3.2230 - val_r2_score: -8.8600
# Epoch 27/50
# 71/73 [============================>.] - ETA: 0s - loss: 2.1086 - root_mean_squared_error: 1.4521 - r2_score: -0.6583
# Epoch 27: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 40ms/step - loss: 2.0949 - root_mean_squared_error: 1.4474 - r2_score: -0.6486 - val_loss: 13.5112 - val_root_mean_squared_error: 3.6758 - val_r2_score: -11.6831
# Epoch 28/50
# 71/73 [============================>.] - ETA: 0s - loss: 1.9670 - root_mean_squared_error: 1.4025 - r2_score: -0.5477
# Epoch 28: val_loss did not improve from 8.17530
# 73/73 [==============================] - 3s 39ms/step - loss: 1.9563 - root_mean_squared_error: 1.3987 - r2_score: -0.5422 - val_loss: 11.7452 - val_root_mean_squared_error: 3.4271 - val_r2_score: -10.1236
# Epoch 28: early stopping
